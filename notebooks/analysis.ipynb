# %%
#Prmsdns 28-11-2025

#This block is used to call any libraries needed in the analysis
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# %%
audio_path = "audio/02. Fame.wav"
file_name_path = "02. Fame.wav"
y,sr = librosa.load(audio_path, sr=None)
print("Audio loaded!")
print("Waveform shape:", y.shape)
print("Sample rate:", sr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 audio_path = "audio/02. Fame.wav"
#       2 file_name_path = "02. Fame.wav"
# ----> 3 y,sr = librosa.load(audio_path, sr=None)
#       4 print("Audio loaded!")
#       5 print("Waveform shape:", y.shape)
#
# NameError: name 'librosa' is not defined
